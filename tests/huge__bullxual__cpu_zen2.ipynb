# %% [markdown]
# ## Wall time VS number of cores

# %%
# !srun -p cpu_zen2 --exclusive cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: AuthenticAMD
# cpu family	: 23
# model		: 49
# model name	: AMD EPYC 7642 48-Core Processor
# stepping	: 0
# microcode	: 0x8301034
# cpu MHz		: 1835.669
# cache size	: 512 KB
# physical id	: 0
# siblings	: 48
# core id		: 0
# cpu cores	: 48
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 16
# wp		: yes
# ...

# %%
# %%bash
# if test ! -f TS_026.rec; then
#     wget --quiet https://ftp.ebi.ac.uk/empiar/world_availability/10988/data/DEF/tomograms/TS_026.rec
# fi
# ln -sf TS_026.rec TS_026.mrc

# %%
# !srun -p cpu_zen2 --exclusive rm -f /dev/shm/vol

# %%
# !srun -p cpu_zen2 --exclusive rm -f /dev/shm/filtered_vol

# %%
# %%time
# !srun -p cpu_zen2 --exclusive python ../flowdenoising.py -i TS_026.mrc -o TS_026__denoised.mrc -v 1 -l 0 -p 96
# Out:
# [2023-02-24 10:48:18,536] (INFO) Verbosity level = 1
# [2023-02-24 10:48:18,536] (INFO) Number of processing units: 96
# [2023-02-24 10:48:18,536] (INFO) sigma=(2.0, 2.0, 2.0)
# [2023-02-24 10:48:18,537] (INFO) reading "TS_026.mrc"
# [2023-02-24 10:48:19,032] (INFO) shape of the input volume (Z, Y, X) = (1000, 928, 960)
# [2023-02-24 10:48:19,032] (INFO) type of the volume = int16
# [2023-02-24 10:48:19,032] (INFO) vol requires 1699.2 MB
# [2023-02-24 10:48:19,130] (INFO) TS_026.mrc max = 168
# [2023-02-24 10:48:19,228] (INFO) TS_026.mrc min = -299
# [2023-02-24 10:48:19,602] (INFO) Input vol average = 2.171719430226293
# [2023-02-24 10:48:19,603] (INFO) read "TS_026.mrc" in 1.0660191141068935 seconds
# [2023-02-24 10:48:19,603] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 10:48:19,620] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 10:48:19,621] (INFO) Computing gaussian kernel with sigma=2.0
# ...

# %%
# %%time
# !srun -p cpu_zen2 --exclusive python ../flowdenoising.py -i TS_026.mrc -o TS_026__denoised.mrc -v 1 -l 0 -p 88
# Out:
# [2023-02-24 10:51:42,575] (INFO) Verbosity level = 1
# [2023-02-24 10:51:42,575] (INFO) Number of processing units: 96
# [2023-02-24 10:51:42,575] (INFO) sigma=(2.0, 2.0, 2.0)
# [2023-02-24 10:51:42,575] (INFO) reading "TS_026.mrc"
# [2023-02-24 10:51:43,053] (INFO) shape of the input volume (Z, Y, X) = (1000, 928, 960)
# [2023-02-24 10:51:43,053] (INFO) type of the volume = int16
# [2023-02-24 10:51:43,053] (INFO) vol requires 1699.2 MB
# [2023-02-24 10:51:43,150] (INFO) TS_026.mrc max = 168
# [2023-02-24 10:51:43,246] (INFO) TS_026.mrc min = -299
# [2023-02-24 10:51:43,621] (INFO) Input vol average = 2.171719430226293
# [2023-02-24 10:51:43,621] (INFO) read "TS_026.mrc" in 1.0455758906900883 seconds
# [2023-02-24 10:51:43,621] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 10:51:43,635] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 10:51:43,635] (INFO) Computing gaussian kernel with sigma=2.0
# ...

# %%
# %%time
# !srun -p cpu_zen2 --exclusive python ../flowdenoising.py -i TS_026.mrc -o TS_026__denoised.mrc -v 1 -l 0 -p 80
# Out:
# [2023-02-24 10:55:04,200] (INFO) Verbosity level = 1
# [2023-02-24 10:55:04,200] (INFO) Number of processing units: 96
# [2023-02-24 10:55:04,200] (INFO) sigma=(2.0, 2.0, 2.0)
# [2023-02-24 10:55:04,200] (INFO) reading "TS_026.mrc"
# [2023-02-24 10:55:04,754] (INFO) shape of the input volume (Z, Y, X) = (1000, 928, 960)
# [2023-02-24 10:55:04,754] (INFO) type of the volume = int16
# [2023-02-24 10:55:04,754] (INFO) vol requires 1699.2 MB
# [2023-02-24 10:55:04,850] (INFO) TS_026.mrc max = 168
# [2023-02-24 10:55:04,944] (INFO) TS_026.mrc min = -299
# [2023-02-24 10:55:05,318] (INFO) Input vol average = 2.171719430226293
# [2023-02-24 10:55:05,318] (INFO) read "TS_026.mrc" in 1.1175855323672295 seconds
# [2023-02-24 10:55:05,318] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 10:55:05,329] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 10:55:05,329] (INFO) Computing gaussian kernel with sigma=2.0
# ...

# %%
# %%time
# !srun -p cpu_zen2 --exclusive python ../flowdenoising.py -i TS_026.mrc -o TS_026__denoised.mrc -v 1 -l 0 -p 72
# Out:
# [2023-02-24 10:58:34,841] (INFO) Verbosity level = 1
# [2023-02-24 10:58:34,841] (INFO) Number of processing units: 96
# [2023-02-24 10:58:34,841] (INFO) sigma=(2.0, 2.0, 2.0)
# [2023-02-24 10:58:34,841] (INFO) reading "TS_026.mrc"
# [2023-02-24 10:58:35,324] (INFO) shape of the input volume (Z, Y, X) = (1000, 928, 960)
# [2023-02-24 10:58:35,324] (INFO) type of the volume = int16
# [2023-02-24 10:58:35,324] (INFO) vol requires 1699.2 MB
# [2023-02-24 10:58:35,420] (INFO) TS_026.mrc max = 168
# [2023-02-24 10:58:35,516] (INFO) TS_026.mrc min = -299
# [2023-02-24 10:58:35,893] (INFO) Input vol average = 2.171719430226293
# [2023-02-24 10:58:35,893] (INFO) read "TS_026.mrc" in 1.0518988966941833 seconds
# [2023-02-24 10:58:35,893] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 10:58:35,909] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 10:58:35,909] (INFO) Computing gaussian kernel with sigma=2.0
# ...

# %%
# %%time
# !srun -p cpu_zen2 --exclusive python ../flowdenoising.py -i TS_026.mrc -o TS_026__denoised.mrc -v 1 -l 0 -p 64
# Out:
# [2023-02-24 11:02:07,766] (INFO) Verbosity level = 1
# [2023-02-24 11:02:07,767] (INFO) Number of processing units: 96
# [2023-02-24 11:02:07,767] (INFO) sigma=(2.0, 2.0, 2.0)
# [2023-02-24 11:02:07,767] (INFO) reading "TS_026.mrc"
# [2023-02-24 11:02:08,272] (INFO) shape of the input volume (Z, Y, X) = (1000, 928, 960)
# [2023-02-24 11:02:08,272] (INFO) type of the volume = int16
# [2023-02-24 11:02:08,272] (INFO) vol requires 1699.2 MB
# [2023-02-24 11:02:08,370] (INFO) TS_026.mrc max = 168
# [2023-02-24 11:02:08,466] (INFO) TS_026.mrc min = -299
# [2023-02-24 11:02:08,840] (INFO) Input vol average = 2.171719430226293
# [2023-02-24 11:02:08,841] (INFO) read "TS_026.mrc" in 1.0737967640161514 seconds
# [2023-02-24 11:02:08,841] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 11:02:08,854] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 11:02:08,855] (INFO) Computing gaussian kernel with sigma=2.0
# ...

# %%
# %%time
# !srun -p cpu_zen2 --exclusive python ../flowdenoising.py -i TS_026.mrc -o TS_026__denoised.mrc -v 1 -l 0 -p 56
# Out:
# [2023-02-24 11:05:48,094] (INFO) Verbosity level = 1
# [2023-02-24 11:05:48,094] (INFO) Number of processing units: 96
# [2023-02-24 11:05:48,094] (INFO) sigma=(2.0, 2.0, 2.0)
# [2023-02-24 11:05:48,094] (INFO) reading "TS_026.mrc"
# [2023-02-24 11:05:48,595] (INFO) shape of the input volume (Z, Y, X) = (1000, 928, 960)
# [2023-02-24 11:05:48,596] (INFO) type of the volume = int16
# [2023-02-24 11:05:48,596] (INFO) vol requires 1699.2 MB
# [2023-02-24 11:05:48,692] (INFO) TS_026.mrc max = 168
# [2023-02-24 11:05:48,790] (INFO) TS_026.mrc min = -299
# [2023-02-24 11:05:49,166] (INFO) Input vol average = 2.171719430226293
# [2023-02-24 11:05:49,167] (INFO) read "TS_026.mrc" in 1.0728405490517616 seconds
# [2023-02-24 11:05:49,167] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 11:05:49,181] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 11:05:49,181] (INFO) Computing gaussian kernel with sigma=2.0
# ...

# %%
# %%time
# !srun -p cpu_zen2 --exclusive python ../flowdenoising.py -i TS_026.mrc -o TS_026__denoised.mrc -v 1 -l 0 -p 48
# Out:
# [2023-02-24 11:09:41,059] (INFO) Verbosity level = 1
# [2023-02-24 11:09:41,059] (INFO) Number of processing units: 96
# [2023-02-24 11:09:41,059] (INFO) sigma=(2.0, 2.0, 2.0)
# [2023-02-24 11:09:41,059] (INFO) reading "TS_026.mrc"
# [2023-02-24 11:09:41,558] (INFO) shape of the input volume (Z, Y, X) = (1000, 928, 960)
# [2023-02-24 11:09:41,559] (INFO) type of the volume = int16
# [2023-02-24 11:09:41,559] (INFO) vol requires 1699.2 MB
# [2023-02-24 11:09:41,655] (INFO) TS_026.mrc max = 168
# [2023-02-24 11:09:41,752] (INFO) TS_026.mrc min = -299
# [2023-02-24 11:09:42,126] (INFO) Input vol average = 2.171719430226293
# [2023-02-24 11:09:42,126] (INFO) read "TS_026.mrc" in 1.0673818998038769 seconds
# [2023-02-24 11:09:42,126] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 11:09:42,140] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 11:09:42,140] (INFO) Computing gaussian kernel with sigma=2.0
# ...

# %%
# %%time
# !srun -p cpu_zen2 --exclusive python ../flowdenoising.py -i TS_026.mrc -o TS_026__denoised.mrc -v 1 -l 0 -p 40
# Out:
# [2023-02-24 11:13:45,425] (INFO) Verbosity level = 1
# [2023-02-24 11:13:45,425] (INFO) Number of processing units: 96
# [2023-02-24 11:13:45,425] (INFO) sigma=(2.0, 2.0, 2.0)
# [2023-02-24 11:13:45,425] (INFO) reading "TS_026.mrc"
# [2023-02-24 11:13:45,928] (INFO) shape of the input volume (Z, Y, X) = (1000, 928, 960)
# [2023-02-24 11:13:45,929] (INFO) type of the volume = int16
# [2023-02-24 11:13:45,929] (INFO) vol requires 1699.2 MB
# [2023-02-24 11:13:46,024] (INFO) TS_026.mrc max = 168
# [2023-02-24 11:13:46,120] (INFO) TS_026.mrc min = -299
# [2023-02-24 11:13:46,494] (INFO) Input vol average = 2.171719430226293
# [2023-02-24 11:13:46,494] (INFO) read "TS_026.mrc" in 1.069381169974804 seconds
# [2023-02-24 11:13:46,494] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 11:13:46,509] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 11:13:46,510] (INFO) Computing gaussian kernel with sigma=2.0
# ...

# %%
# %%time
# !srun -p cpu_zen2 --exclusive python ../flowdenoising.py -i TS_026.mrc -o TS_026__denoised.mrc -v 1 -l 0 -p 32
# Out:
# [2023-02-24 14:06:19,495] (INFO) Verbosity level = 1
# [2023-02-24 14:06:19,496] (INFO) Number of processing units: 96
# [2023-02-24 14:06:19,496] (INFO) sigma=(2.0, 2.0, 2.0)
# [2023-02-24 14:06:19,496] (INFO) reading "TS_026.mrc"
# [2023-02-24 14:06:25,718] (INFO) shape of the input volume (Z, Y, X) = (1000, 928, 960)
# [2023-02-24 14:06:25,718] (INFO) type of the volume = int16
# [2023-02-24 14:06:25,719] (INFO) vol requires 1699.2 MB
# [2023-02-24 14:06:25,816] (INFO) TS_026.mrc max = 168
# [2023-02-24 14:06:25,912] (INFO) TS_026.mrc min = -299
# [2023-02-24 14:06:26,288] (INFO) Input vol average = 2.171719430226293
# [2023-02-24 14:06:26,288] (INFO) read "TS_026.mrc" in 6.792633503675461 seconds
# [2023-02-24 14:06:26,288] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 14:06:26,301] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 14:06:26,302] (INFO) Computing gaussian kernel with sigma=2.0
# ...

# %%
# %%time
# !srun -p cpu_zen2 --exclusive python ../flowdenoising.py -i TS_026.mrc -o TS_026__denoised.mrc -v 1 -l 0 -p 24
# Out:
# [2023-02-24 14:11:31,209] (INFO) Verbosity level = 1
# [2023-02-24 14:11:31,210] (INFO) Number of processing units: 96
# [2023-02-24 14:11:31,210] (INFO) sigma=(2.0, 2.0, 2.0)
# [2023-02-24 14:11:31,210] (INFO) reading "TS_026.mrc"
# [2023-02-24 14:11:31,748] (INFO) shape of the input volume (Z, Y, X) = (1000, 928, 960)
# [2023-02-24 14:11:31,749] (INFO) type of the volume = int16
# [2023-02-24 14:11:31,749] (INFO) vol requires 1699.2 MB
# [2023-02-24 14:11:31,845] (INFO) TS_026.mrc max = 168
# [2023-02-24 14:11:31,939] (INFO) TS_026.mrc min = -299
# [2023-02-24 14:11:32,315] (INFO) Input vol average = 2.171719430226293
# [2023-02-24 14:11:32,315] (INFO) read "TS_026.mrc" in 1.105188176035881 seconds
# [2023-02-24 14:11:32,315] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 14:11:32,329] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 14:11:32,330] (INFO) Computing gaussian kernel with sigma=2.0
# ...

# %%
# %%time
# !srun -p cpu_zen2 --exclusive python ../flowdenoising.py -i TS_026.mrc -o TS_026__denoised.mrc -v 1 -l 0 -p 16
# Out:
# [2023-02-24 14:17:52,296] (INFO) Verbosity level = 1
# [2023-02-24 14:17:52,296] (INFO) Number of processing units: 96
# [2023-02-24 14:17:52,296] (INFO) sigma=(2.0, 2.0, 2.0)
# [2023-02-24 14:17:52,296] (INFO) reading "TS_026.mrc"
# [2023-02-24 14:17:52,831] (INFO) shape of the input volume (Z, Y, X) = (1000, 928, 960)
# [2023-02-24 14:17:52,831] (INFO) type of the volume = int16
# [2023-02-24 14:17:52,831] (INFO) vol requires 1699.2 MB
# [2023-02-24 14:17:52,927] (INFO) TS_026.mrc max = 168
# [2023-02-24 14:17:53,021] (INFO) TS_026.mrc min = -299
# [2023-02-24 14:17:53,394] (INFO) Input vol average = 2.171719430226293
# [2023-02-24 14:17:53,394] (INFO) read "TS_026.mrc" in 1.0981583707034588 seconds
# [2023-02-24 14:17:53,394] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 14:17:53,408] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 14:17:53,409] (INFO) Computing gaussian kernel with sigma=2.0
# ...

# %%
# %%time
# !srun -p cpu_zen2 --exclusive python ../flowdenoising.py -i TS_026.mrc -o TS_026__denoised.mrc -v 1 -l 0 -p 8
# Out:
# [2023-02-24 14:27:00,781] (INFO) Verbosity level = 1
# [2023-02-24 14:27:00,781] (INFO) Number of processing units: 96
# [2023-02-24 14:27:00,781] (INFO) sigma=(2.0, 2.0, 2.0)
# [2023-02-24 14:27:00,781] (INFO) reading "TS_026.mrc"
# [2023-02-24 14:27:01,310] (INFO) shape of the input volume (Z, Y, X) = (1000, 928, 960)
# [2023-02-24 14:27:01,311] (INFO) type of the volume = int16
# [2023-02-24 14:27:01,311] (INFO) vol requires 1699.2 MB
# [2023-02-24 14:27:01,407] (INFO) TS_026.mrc max = 168
# [2023-02-24 14:27:01,503] (INFO) TS_026.mrc min = -299
# [2023-02-24 14:27:01,877] (INFO) Input vol average = 2.171719430226293
# [2023-02-24 14:27:01,878] (INFO) read "TS_026.mrc" in 1.0965041443705559 seconds
# [2023-02-24 14:27:01,878] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 14:27:01,899] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 14:27:01,899] (INFO) Computing gaussian kernel with sigma=2.0
# ...

# %%
# %%time
# !srun -p cpu_zen2 --exclusive python ../flowdenoising.py -i TS_026.mrc -o TS_026__denoised.mrc -v 1 -l 0 -p 4
# Out:
# [2023-02-24 14:44:17,266] (INFO) Verbosity level = 1
# [2023-02-24 14:44:17,267] (INFO) Number of processing units: 96
# [2023-02-24 14:44:17,267] (INFO) sigma=(2.0, 2.0, 2.0)
# [2023-02-24 14:44:17,267] (INFO) reading "TS_026.mrc"
# [2023-02-24 14:44:17,872] (INFO) shape of the input volume (Z, Y, X) = (1000, 928, 960)
# [2023-02-24 14:44:17,872] (INFO) type of the volume = int16
# [2023-02-24 14:44:17,872] (INFO) vol requires 1699.2 MB
# [2023-02-24 14:44:17,969] (INFO) TS_026.mrc max = 168
# [2023-02-24 14:44:18,066] (INFO) TS_026.mrc min = -299
# [2023-02-24 14:44:18,441] (INFO) Input vol average = 2.171719430226293
# [2023-02-24 14:44:18,441] (INFO) read "TS_026.mrc" in 1.1745141446590424 seconds
# [2023-02-24 14:44:18,441] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 14:44:18,460] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 14:44:18,461] (INFO) Computing gaussian kernel with sigma=2.0
# ...

# %%
# %%time
# !srun -p cpu_zen2 --exclusive python ../flowdenoising.py -i TS_026.mrc -o TS_026__denoised.mrc -v 1 -l 0 -p 2
# Out:
# [2023-02-24 15:17:53,535] (INFO) Verbosity level = 1
# [2023-02-24 15:17:53,535] (INFO) Number of processing units: 96
# [2023-02-24 15:17:53,535] (INFO) sigma=(2.0, 2.0, 2.0)
# [2023-02-24 15:17:53,535] (INFO) reading "TS_026.mrc"
# [2023-02-24 15:17:54,037] (INFO) shape of the input volume (Z, Y, X) = (1000, 928, 960)
# [2023-02-24 15:17:54,037] (INFO) type of the volume = int16
# [2023-02-24 15:17:54,037] (INFO) vol requires 1699.2 MB
# [2023-02-24 15:17:54,134] (INFO) TS_026.mrc max = 168
# [2023-02-24 15:17:54,230] (INFO) TS_026.mrc min = -299
# [2023-02-24 15:17:54,602] (INFO) Input vol average = 2.171719430226293
# [2023-02-24 15:17:54,602] (INFO) read "TS_026.mrc" in 1.0670353285968304 seconds
# [2023-02-24 15:17:54,602] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 15:17:54,615] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 15:17:54,616] (INFO) Computing gaussian kernel with sigma=2.0
# ...

# %%
# %%time
# !srun -p cpu_zen2 --exclusive python ../flowdenoising.py -i TS_026.mrc -o TS_026__denoised.mrc -v 1 -l 0 -p 1
# Out:
# srun: job 527221 queued and waiting for resources
# srun: job 527221 has been allocated resources
# [2023-02-24 18:12:56,423] (INFO) Verbosity level = 1
# [2023-02-24 18:12:56,423] (INFO) Number of processing units: 96
# [2023-02-24 18:12:56,423] (INFO) sigma=(2.0, 2.0, 2.0)
# [2023-02-24 18:12:56,423] (INFO) reading "TS_026.mrc"
# [2023-02-24 18:12:57,169] (INFO) shape of the input volume (Z, Y, X) = (1000, 928, 960)
# [2023-02-24 18:12:57,169] (INFO) type of the volume = int16
# [2023-02-24 18:12:57,169] (INFO) vol requires 1699.2 MB
# [2023-02-24 18:12:57,266] (INFO) TS_026.mrc max = 168
# [2023-02-24 18:12:57,362] (INFO) TS_026.mrc min = -299
# [2023-02-24 18:12:57,739] (INFO) Input vol average = 2.171719430226293
# [2023-02-24 18:12:57,739] (INFO) read "TS_026.mrc" in 1.3162312731146812 seconds
# [2023-02-24 18:12:57,739] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 18:12:57,750] (INFO) Computing gaussian kernel with sigma=2.0
# ...

# %%
# %%time
# !srun -p cpu_zen2 --exclusive python ../flowdenoising_sequential.py -i TS_026.mrc -o TS_026__denoised.mrc -v 1 -l 0
# Out:
# [2023-02-24 20:22:20,300] (INFO) Verbosity level = 1
# [2023-02-24 20:22:20,300] (INFO) 0 %
# [2023-02-24 20:22:20,301] (INFO) sigma=(2.0, 2.0, 2.0)
# [2023-02-24 20:22:20,301] (INFO) reading "TS_026.mrc"
# [2023-02-24 20:22:20,821] (INFO) shape of the input volume (Z, Y, X) = (1000, 928, 960)
# [2023-02-24 20:22:20,822] (INFO) type of the volume = int16
# [2023-02-24 20:22:20,822] (INFO) read "TS_026.mrc" in 0.5209282636642456 seconds
# [2023-02-24 20:22:20,822] (INFO) TS_026.mrc type = int16
# [2023-02-24 20:22:20,918] (INFO) TS_026.mrc max = 168
# [2023-02-24 20:22:21,015] (INFO) TS_026.mrc min = -299
# [2023-02-24 20:22:21,302] (INFO) 0 %
# [2023-02-24 20:22:21,389] (INFO) Input vol average = 2.171719430226293
# [2023-02-24 20:22:21,389] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 20:22:21,390] (INFO) Computing gaussian kernel with sigma=2.0
# [2023-02-24 20:22:21,391] (INFO) Computing gaussian kernel with sigma=2.0
# ...
